# %% [markdown]
# <a href="https://colab.research.google.com/github/Azhari-Kemalasari/Python/blob/main/Sales_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Cleaning dengan Python**
# Data Cleaning dilakukan agar analisis data menjadi valid dan tidak terjadi kesalahan.
# **Data Cleaning Steps**
# 1. Import Library
# Langkah awal yaitu import library yang dibutuhkan data cleaning dan data visualization:
#
# ```
# import pandas as pd
# import numpy as np #library Python yg memudahkan kita melakukan perhitungan scientific seperti matriks, aljabar, statistik, dsb.
# import matplotlib.pyplot as plt #untuk visualisasi
# import matplotlib as mpl
# import seaborn as sns #untuk memproduksi visualisasi dengan python
# ```

# %%
#import library
from google.colab import drive #import dataset
drive.mount('/content/drive/')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import dataset'
df_sales = pd.read_excel('/content/drive/MyDrive/Dataset/sales_dataset.xlsx')

#Menampilkan bentuk dataset
print(df_sales.shape) #ouput (Baris,Kolom)

#menampilkan head dataset
df_sales.head()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# (3339, 13)
#    OrderID       Date  CustomerID         Customers  \
# 0        1 2020-01-01        1866    Farrand Vasler
# 1        2 2020-01-01        1567   Terencio McKern
# 2        3 2020-01-01        2064  Geordie Stiggers
# 3        4 2020-01-01         287    Elna De Angelo
# 4        5 2020-01-01         422     Lucita Lesper
#
#               Customers Email      Customer Address     Customer City  \
# 0       fvaslerqt@comsenz.com      134 Melrose Pass           Jackson
# 1       tmckernot@tinyurl.com          26 Muir Lane              Katy
# 2  gstiggersdd@eventbrite.com  11106 Cordelia Plaza  Saint Petersburg
# 3                edew@nba.com        78 Shasta Park          Honolulu
# 4           llespercx@com.com   393 Holmberg Center        Des Moines
#
#   ProdNumber            Product Name    Category Name  Product Price  \
# ...

# %%
#Menampilkan Info Dataset
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3339 entries, 0 to 3338
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           3339 non-null   int64
#  1   Date              3339 non-null   datetime64[ns]
#  2   CustomerID        3339 non-null   int64
#  3   Customers         3339 non-null   object
#  4   Customers Email   3339 non-null   object
#  5   Customer Address  3339 non-null   object
#  6   Customer City     3339 non-null   object
#  7   ProdNumber        3339 non-null   object
#  8   Product Name      3339 non-null   object
#  9   Category Name     3339 non-null   object
#  10  Product Price     3339 non-null   float64
#  11  Quantity          3339 non-null   int64
#  12  Total Sales       3339 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(7)
# memory usage: 339.2+ KB

# %%
#Mengurutkan dataset secara ascending berdasarkan kolom date
df_sales = df_sales.sort_values(by='Date', ascending=True)

# %%
df_sales.head()
# Out:
#    OrderID       Date  CustomerID         Customers  \
# 0        1 2020-01-01        1866    Farrand Vasler
# 1        2 2020-01-01        1567   Terencio McKern
# 2        3 2020-01-01        2064  Geordie Stiggers
# 3        4 2020-01-01         287    Elna De Angelo
# 4        5 2020-01-01         422     Lucita Lesper
#
#               Customers Email      Customer Address     Customer City  \
# 0       fvaslerqt@comsenz.com      134 Melrose Pass           Jackson
# 1       tmckernot@tinyurl.com          26 Muir Lane              Katy
# 2  gstiggersdd@eventbrite.com  11106 Cordelia Plaza  Saint Petersburg
# 3                edew@nba.com        78 Shasta Park          Honolulu
# 4           llespercx@com.com   393 Holmberg Center        Des Moines
#
#   ProdNumber            Product Name    Category Name  Product Price  \
# 0      EB514            Polar Robots           eBooks          23.99
# 1      RS706            RWW-75 Robot           Robots         883.00
# ...

# %%
#Menemukan berapa customer
df_sales['Customers'].unique()
# Out:
# array(['Farrand Vasler', 'Terencio McKern', 'Geordie Stiggers', ...,
#        'Alexandra Stamp', 'Nydia Gyse', 'Robby Drinkale'], dtype=object)

# %%
#
df_sales['Customers'].nunique()
# Out:
# 1671
